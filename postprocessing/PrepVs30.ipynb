# %% [markdown]
# ## Visualization of simulation data and comparison

# %%
### load module
# %matplotlib inline
#import instaseis
import numpy as np
import matplotlib.pyplot as plt
# import h5py
import pandas as pd
import seissolxdmf 
import os, sys

import pyproj
# import scipy.io as sio
import matplotlib.tri as tri

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# from mpl_toolkits.basemap import Basemap
# from scipy import spatial
# from netCDF4 import Dataset

# from scipy import spatial
# from netCDF4 import Dataset

# import seaborn as sns

# c_blue=['#2878B5','#9AC9DB'];
# c_red=['#C82423','#F8AC8C','#FF8884'];
# c_gre=['#96C37D','#8ECFC9'];
# c_pur=['#8B8EFE','#C497B2'];

# colors2=sns.color_palette("rocket",8);
print('load modulus')
# Out:
# load modulus

# %%
import palettable.matplotlib as cmapa
from palettable.cmocean import sequential as cmapb
from palettable.cmocean import diverging as cmapc

from matplotlib.colors import ListedColormap

Cmap1 = ListedColormap(cmapa.Inferno_14.mpl_colors)
Cmap1

Cmap2 = ListedColormap(cmapb.Deep_14.mpl_colors)
Cmap2

Cmap3 = ListedColormap(cmapc.Balance_20.mpl_colors)
Cmap3

# %%
# load surface static GPS displacement and compare

import matplotlib
from matplotlib.ticker import MultipleLocator
print(matplotlib.style.available)

# matplotlib.rc('font', **font)
matplotlib.style.use('seaborn-v0_8-talk') # Lovely plotting style

lla = pyproj.Proj(proj='latlong', ellps='WGS84', datum='WGS84')
myproj = pyproj.Proj( init='EPSG:2193',ellps='WGS84', datum='WGS84')
figsize_single=(6,4.5)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# /Users/DuoL/opt/miniconda3/envs/obspy/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
from PIL import Image
import numpy as np

# Open the TIFF file
img = Image.open('vs30/vs30/'+"vs30_slope.tif")

# Print some basic information
print("Format:", img.format)  # e.g., TIFF
print("Size:", img.size)      # (width, height)
print("Mode:", img.mode)      # e.g., "RGB", "L" for grayscale

# Convert to a NumPy array (useful for further processing)
img_array = np.array(img)
print("Array shape:", img_array.shape)
# Out:
# ---------------------------------------------------------------------------
# DecompressionBombError                    Traceback (most recent call last)
# Cell In[2], line 5
#       2 import numpy as np
#       4 # Open the TIFF file
# ----> 5 img = Image.open('vs30/vs30/'+"vs30_slope.tif")
#       7 # Print some basic information
#       8 print("Format:", img.format)  # e.g., TIFF
#
# File ~/opt/miniconda3/envs/obspy/lib/python3.10/site-packages/PIL/Image.py:3323, in open(fp, mode, formats)
#    3321     checked_formats = formats.copy()
#    3322     if init():
# -> 3323         im = _open_core(
#    3324             fp,
#    3325             filename,
#    3326             prefix,
#    3327             tuple(format for format in formats if format not in checked_formats),
#    3328         )
#    3330 if im:
#    3331     im._exclusive_fp = exclusive_fp
#
# File ~/opt/miniconda3/envs/obspy/lib/python3.10/site-packages/PIL/Image.py:3305, in open.<locals>._open_core(fp, filename, prefix, formats)
#    3303         fp.seek(0)
#    3304         im = factory(fp, filename)
# -> 3305         _decompression_bomb_check(im.size)
#    3306         return im
#    3307 except (SyntaxError, IndexError, TypeError, struct.error):
#    3308     # Leave disabled by default, spams the logs with image
#    3309     # opening failures that are entirely expected.
#    3310     # logger.debug("", exc_info=True)
#
# File ~/opt/miniconda3/envs/obspy/lib/python3.10/site-packages/PIL/Image.py:3215, in _decompression_bomb_check(size)
#    3210 if pixels > 2 * MAX_IMAGE_PIXELS:
#    3211     msg = (
#    3212         f"Image size ({pixels} pixels) exceeds limit of {2 * MAX_IMAGE_PIXELS} "
#    3213         "pixels, could be decompression bomb DOS attack."
#    3214     )
# -> 3215     raise DecompressionBombError(msg)
#    3217 if pixels > MAX_IMAGE_PIXELS:
#    3218     warnings.warn(
#    3219         f"Image size ({pixels} pixels) exceeds limit of {MAX_IMAGE_PIXELS} pixels, "
#    3220         "could be decompression bomb DOS attack.",
#    3221         DecompressionBombWarning,
#    3222     )
#
# DecompressionBombError: Image size (725820001 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
